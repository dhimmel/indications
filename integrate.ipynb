# %%
import os
import pandas
import numpy

# %%
# read MEDI
path = os.path.join('medi', 'data', 'medi-umls.tsv')
medi = pandas.read_csv(path, sep='\t')
medi = medi.query('hps == 1')
medi[:5]
# Out:
#    rxnorm_id drug_name disease_cui disease_icd9  \
# 4         44     Mesna    C0019080        459.0
# 5         44     Mesna    C0010692          595
# 6         44     Mesna    C0010692        595.9
# 7         44     Mesna    C0085692        595.9
# 8         44     Mesna    C0013221        977.9
#
#                                         disease_name  n_resources  hps  \
# 4                                     Hemorrhage NOS            1    1
# 5                                           Cystitis            2    1
# 6                                       Cystitis NOS            3    1
# 7                                       Cystitis NOS            3    1
# 8  Poisoning by unspecified drug or medicinal sub...            1    1
#
#    on_label
# 4         0
# 5         1
# 6         1
# 7         1
# 8         0

# %%
# read LabeledIn
path = os.path.join('labeledin', 'data', 'indications.tsv')
labin = pandas.read_csv(path, sep='\t')
labin[:5]
# Out:
#   rxnorm_id disease_cui  n_labels  expert  crowd        disease_mesh_name  \
# 0     10156    C0013295         2       1      0           Duodenal Ulcer
# 1     10237    C0003873         1       0      1    Arthritis, Rheumatoid
# 2     10237    C0029408         1       0      1           Osteoarthritis
# 3     10237    C0038013         1       0      1  Spondylitis, Ankylosing
# 4     10237    C0149896         1       0      1                      NaN
#
#   rxnorm_name
# 0  Sucralfate
# 1    Sulindac
# 2    Sulindac
# 3    Sulindac
# 4    Sulindac

# %%
# read EHRLink
path = os.path.join('ehrlink', 'download', 'amiajnl-2012-000852-s1.tsv')
ehrlink = pandas.read_csv(path, sep='\t')
#ehrlink[:5]

#ehrlink_meds = ehrlink[['medication_definition_id', 'medication']].drop_duplicates()
#ehrlink_meds.ix[numpy.random.choice(ehrlink_meds.index.values, 5)]

#ehrlink_probs = ehrlink[['problem_definition_id', 'problem']].drop_duplicates()
#ehrlink_probs.ix[numpy.random.choice(ehrlink_probs.index.values, 5)]

# %%
url = 'http://git.dhimmel.com/disease-ontology/data/xrefs-prop.tsv'
pandas.read_csv(url, sep='\t')
# Out:
#            doid_code                              doid_name  \
# 0             DOID:4                                disease
# 1             DOID:4                                disease
# 2             DOID:4                                disease
# 3             DOID:4                                disease
# 4             DOID:4                                disease
# 5             DOID:4                                disease
# 6             DOID:4                                disease
# 7             DOID:4                                disease
# 8             DOID:4                                disease
# 9             DOID:4                                disease
# 10            DOID:4                                disease
# 11            DOID:4                                disease
# 12            DOID:4                                disease
# 13            DOID:4                                disease
# 14            DOID:4                                disease
# ...

# %%
"""

"""
